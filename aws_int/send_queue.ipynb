# %%
import dotenv
import json
import boto3
import os

dotenv.load_dotenv()
# Out:
# True

# %%
sqs = boto3.client("sqs",
                   region_name=os.getenv('AWS_REGION'),
                   aws_access_key_id=os.getenv('AWS_ACCESS_KEY_ID'),
                   aws_secret_access_key=os.getenv('AWS_SECRET_ACCESS_KEY'))

queue_url = os.getenv('SQS_QUEUE_URL')

payload = {
    "id": 4,
    "produto": "abc",
    "valor": 100
}

sqs.send_message(
    QueueUrl=queue_url,
    MessageBody=json.dumps(payload)
)
# Out:
# {'MD5OfMessageBody': '13b91982f07342defa7fa95d6da3bb84',
#  'MessageId': '5da4c4cf-e516-44dc-b260-cce6ec8c4290',
#  'ResponseMetadata': {'RequestId': '118c2564-14f1-538f-8af4-4755073bd669',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '118c2564-14f1-538f-8af4-4755073bd669',
#    'date': 'Sun, 15 Mar 2026 20:07:38 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '106',
#    'connection': 'keep-alive'},
#   'RetryAttempts': 0}}
