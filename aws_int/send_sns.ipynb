# %%
import dotenv
import json
import boto3
import os

dotenv.load_dotenv()
# Out:
# True

# %%
sns = boto3.client("sns",
                   region_name=os.getenv('AWS_REGION'),
                   aws_access_key_id=os.getenv('AWS_ACCESS_KEY_ID'),
                   aws_secret_access_key=os.getenv('AWS_SECRET_ACCESS_KEY'))

topic_arn = os.getenv('SNS_TOPIC_ARN')

payload = {
    "id": 6,
    "produto": "abc",
    "valor": 200
}

sns.publish(
    TopicArn=topic_arn,
    Message=json.dumps(payload)
)
# Out:
# {'MessageId': '26ab1aec-cdde-5048-ba1f-78d5c00bf5a5',
#  'ResponseMetadata': {'RequestId': '6cb738e2-ba5a-5934-8a1d-5adbb78fecd9',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '6cb738e2-ba5a-5934-8a1d-5adbb78fecd9',
#    'date': 'Sat, 21 Mar 2026 21:20:21 GMT',
#    'content-type': 'text/xml',
#    'content-length': '294',
#    'connection': 'keep-alive'},
#   'RetryAttempts': 0}}
