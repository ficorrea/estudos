# %%
l = [4,1,2,1,2]
print(0 ^ l[0])
print(4 ^ l[1])
print(5 ^ l[2])
print(7 ^ l[3])
print(6 ^ l[2])
# Out:
# 4
# 5
# 7
# 6
# 4

# %%
from itertools import product

# %%
la = ['nomeA', 'nomeB', 'nomeC']
lb = ['descA', 'descB', 'descC', 'descD', 'descE']

# %%
[(b, a) for a, b in product(la, lb)]
# Out:
# [('descA', 'nomeA'),
#  ('descB', 'nomeA'),
#  ('descC', 'nomeA'),
#  ('descD', 'nomeA'),
#  ('descE', 'nomeA'),
#  ('descA', 'nomeB'),
#  ('descB', 'nomeB'),
#  ('descC', 'nomeB'),
#  ('descD', 'nomeB'),
#  ('descE', 'nomeB'),
#  ('descA', 'nomeC'),
#  ('descB', 'nomeC'),
#  ('descC', 'nomeC'),
#  ('descD', 'nomeC'),
#  ('descE', 'nomeC')]
